# %%
# This Python Notebook is created for the submission of my First assignment Of Capstone project of Data science.

import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
